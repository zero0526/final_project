# %%
# !git clone https://github.com/zero0526/final_project.git
# %cd final_project
# !git checkout test_env
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_799/2795035367.py in <cell line: 0>()
# ----> 1 from matrix_source.trainers.train import Trainer
#       2 from matrix_source.trainers.ppo_stategy import PPOStrategy
#       3 from matrix_source.trainers.d3qn_strategy import D3QNStrategy
#       4 from matrix_source.trainers.d3qn_scaffold_strategy_v2 import D3QNScaffoldStrategy
#       5 from matrix_source.trainers.semi_distribute_task import GRUPPOSCAFFOLDREPStrategy
#
# ModuleNotFoundError: No module named 'matrix_source'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import os
import sys

repo_name = 'final_project'
os.chdir(f'/content/{repo_name}')
os.makedirs("/content/final_project/data/plots", exist_ok=True)
sys.path.append(os.getcwd())

print(f"Thư mục hiện tại: {os.getcwd()}")
# Out:
# /content

# %%
from matrix_source.trainers.train import Trainer
from matrix_source.trainers.ppo_stategy import PPOStrategy
from matrix_source.trainers.d3qn_strategy import D3QNStrategy
from matrix_source.trainers.d3qn_scaffold_strategy_v2 import D3QNScaffoldStrategy

from matrix_source.trainers.rb_sac_cen_stra_copy import RB_SAC_CEN_STRA

if __name__ == '__main__':
    strategy = D3QNStrategy()
    trainer = Trainer(strategy=strategy)
    trainer.train()
